# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# a = range(0,232)
# keys = map(lambda x: str(x), a)

data = pd.read_csv('aproximation_data.txt', sep=",", header = None)
# data.columns = keys
# data = data[data['231'] != -1]
print data
# Out:
#             0         1         2         3         4         5         6   \
# 0      0.31831  0.017440  0.010197  0.014085  0.025656  0.022409  0.022317
# 1      0.31831  0.014705  0.008857  0.012645  0.024486  0.019805  0.019853
# 2      0.31831  0.015978  0.009522  0.013792  0.026751  0.021729  0.020519
# 3      0.31831  0.014327  0.008701  0.013076  0.025606  0.020028  0.019547
# 4      0.31831  0.014145  0.008371  0.013127  0.026156  0.019933  0.019681
# 5      0.31831  0.007333  0.053617  0.012933  0.028949  0.001846  0.022861
# 6      0.31831  0.013715  0.008154  0.013234  0.026318  0.019530  0.019547
# 7      0.31831  0.014740  0.008482  0.014503  0.028510  0.021144  0.020160
# 8      0.31831  0.012432  0.007696  0.012807  0.026197  0.018173  0.019939
# 9      0.31831  0.014480  0.006905  0.014848  0.030078  0.020073  0.020821
# 10     0.31831  0.015365  0.005952  0.015739  0.032674  0.020930  0.021945
# ...

# %%
a = range(0,5)
keys = map(lambda x: str(x), a)
read = pd.read_csv('test.txt', sep=",", header = None)
read.columns = keys 
print read
# read = read[~read['4'].str.contains("oi")]
print read['4'].tolist()
# Out:
#      0     1     2  3       4
# 0  0.2  0.30  0.50  1      oi
# 1  0.2  0.61  0.52  0     ola
# 2  0.1  0.27  0.42  1   hello
# 3  0.8  0.19  0.50  0     hey
# [' oi', ' ola', ' hello', ' hey']

# %%
lista = ['oi','hello']
for elem in lista:
    read = read[~read['4'].str.contains(elem)]
print read
# Out:
#      0     1     2  3     4
# 1  0.2  0.61  0.52  0   ola
# 3  0.8  0.19  0.50  0   hey

# %%
read.to_csv('write_test.txt', header=None, index=None, sep=',', mode='a')

# %%
reap = ['oi', 'oi', 'helo', 'hey']
reap = list(set(reap))
print reap
# Out:
# ['helo', 'hey', 'oi']

# %%
apro = pd.read_csv('aproximation_data.txt', sep=",", header = None)
print len(apro.columns)
# Out:
# 27
