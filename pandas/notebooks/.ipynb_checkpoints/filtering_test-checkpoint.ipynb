# %%
import pandas as pd
import numpy as np

# %%
a = range(0,232)
keys = map(lambda x: str(x), a)

data = pd.read_csv('aproximation_data.txt', sep=",", header = None)
data.columns = keys
# data = data[data['231'] != -1]
print data['0']
# Out:
#          0         1         2         3         4         5         6   \
# 10  0.31831  0.015365  0.005952  0.015739  0.032674  0.020930  0.021945
# 11  0.31831  0.013510  0.004373  0.014298  0.030643  0.018233  0.022302
# 12  0.31831  0.010042  0.002832  0.011436  0.025875  0.014312  0.021043
# 13  0.31831  0.010713  0.001702  0.012331  0.028251  0.015185  0.022556
# 14  0.31831  0.014501  0.000644  0.015951  0.035521  0.019224  0.026393
# 15  0.31831  0.012656  0.000077  0.014147  0.032894  0.016864  0.026454
# 16  0.31831  0.007686  0.054807  0.013607  0.029808  0.001893  0.021707
# 17  0.31831  0.013273  0.001409  0.015285  0.035259  0.017758  0.027071
# 18  0.31831  0.012466  0.001611  0.014803  0.034256  0.017298  0.026964
# 19  0.31831  0.012078  0.002328  0.014601  0.034375  0.017105  0.026829
#
#           7         8         9                 ...                       17  \
# 10  0.014763  0.008117  0.025414                ...                 0.023137
# ...
